# %%
import requests
import xarray as xr
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
import copernicusmarine
# meta data here https://data-be-prd.marine.copernicus.eu/api/metadata/SEALEVEL_GLO_PHY_CLIMATE_L4_MY_008_057
# Set parameters
data_request = {
   "longitude" : [-85, -55], 
   "latitude" : [30, 45],
   "time" : ["1992-01-01", "2017-12-30"],
   "variables" : ["ugos", "ugosa", "vgos", "vgosa"]
}

sss_l3s = copernicusmarine.open_dataset(
    dataset_id = "cmems_obs-sl_glo_phy-ssh_my_allsat-l4-duacs-0.25deg_P1D",
    minimum_longitude = data_request["longitude"][0],
    maximum_longitude = data_request["longitude"][1],
    minimum_latitude = data_request["latitude"][0],
    maximum_latitude = data_request["latitude"][1],
    start_datetime = data_request["time"][0],
    end_datetime = data_request["time"][1],
    username = "ameza",
    password = "Ameza1998", 
    variables = data_request["variables"]
)
# Out:
# Fetching catalog: 100%|███████████████████████████| 3/3 [00:27<00:00,  9.10s/it]
# INFO - 2024-05-05T21:50:30Z - Dataset version was not specified, the latest one was selected: "202112"
# INFO - 2024-05-05T21:50:30Z - Dataset part was not specified, the first one was selected: "default"
# INFO - 2024-05-05T21:50:38Z - Service was not specified, the default one was selected: "arco-time-series"
# WARNING - 2024-05-05T21:50:42Z - Some or all of your subset selection [1992-01-01 00:00:00, 2017-12-30 00:00:00] for the time dimension  exceed the dataset coordinates [1993-01-01 00:00:00, 2023-06-07 00:00:00]

# %%
ssh = sss_l3s.compute()

# %%
sss_l3s.to_netcdf("cmems_geos_vel.nc",  
                  compute = True, 
                  engine = "netcdf4")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sss_l3s.to_netcdf("cmems_geos_vel.nc", format = "NETCDF4", compute = True)
#
# File ~/miniforge3/lib/python3.10/site-packages/xarray/core/dataset.py:2298, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    2295     encoding = {}
#    2296 from xarray.backends.api import to_netcdf
# -> 2298 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    2299     self,
#    2300     path,
#    2301     mode=mode,
#    2302     format=format,
#    2303     group=group,
#    2304     engine=engine,
#    2305     encoding=encoding,
#    2306     unlimited_dims=unlimited_dims,
#    2307     compute=compute,
#    2308     multifile=False,
#    2309     invalid_netcdf=invalid_netcdf,
#    2310 )
#
# ...

# %%
sss_l3s.ugos.isel(time = 0).drop("time").compute().plot()
# Out:
# /var/folders/k7/tch_9kz957x4jxjqlctv2shc0000gn/T/ipykernel_35949/3361480243.py:1: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   sss_l3s.ugos.isel(time = 0).drop("time").compute().plot()
